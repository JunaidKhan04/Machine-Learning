# %%
# Immport Important Libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv(r"D:\Machine Learning\Machine-Learning\Regression\Multiple Linear Regression\housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
# drop ocean_proximity column

df.drop('ocean_proximity',axis=1,inplace=True)
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
# Correlation
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
# Corr with target variable
df.corr()['total_bedrooms']
# Out:
# longitude             0.069608
# latitude             -0.066983
# housing_median_age   -0.320451
# total_rooms           0.930380
# total_bedrooms        1.000000
# population            0.877747
# households            0.979728
# median_income        -0.007723
# median_house_value    0.049686
# Name: total_bedrooms, dtype: float64

# %%
# These attributes are strongly correlated
housing = df[['total_rooms','population','households','total_bedrooms']]
housing.head()
# Out:
#    total_rooms  population  households  total_bedrooms
# 0        880.0       322.0       126.0           129.0
# 1       7099.0      2401.0      1138.0          1106.0
# 2       1467.0       496.0       177.0           190.0
# 3       1274.0       558.0       219.0           235.0
# 4       1627.0       565.0       259.0           280.0

# %%
# Correlation
housing.corr()
# Out:
#                 total_rooms  population  households  total_bedrooms
# total_rooms        1.000000    0.857126    0.918484        0.930380
# population         0.857126    1.000000    0.907222        0.877747
# households         0.918484    0.907222    1.000000        0.979728
# total_bedrooms     0.930380    0.877747    0.979728        1.000000

# %%
# Nulls
housing.isnull().sum()
# Out:
# total_rooms         0
# population          0
# households          0
# total_bedrooms    207
# dtype: int64

# %%
# Check Nulls
#!pip install missingno
#import Library
import missingno as msno
